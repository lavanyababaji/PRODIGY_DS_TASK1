# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/lavan/Downloads/all_weekly_excess_deaths.csv')

# %%
df
# Out:
#             country         region  start_date    end_date  days  year  week  \
# 0         Australia      Australia  30-12-2019  05-01-2020     7  2020     1
# 1         Australia      Australia  06-01-2020  12-01-2020     7  2020     2
# 2         Australia      Australia  13-01-2020  19-01-2020     7  2020     3
# 3         Australia      Australia  20-01-2020  26-01-2020     7  2020     4
# 4         Australia      Australia  27-01-2020  02-02-2020     7  2020     5
# ...             ...            ...         ...         ...   ...   ...   ...
# 5765  United States  United States  09-05-2022  15-05-2022     7  2022    19
# 5766  United States  United States  16-05-2022  22-05-2022     7  2022    20
# 5767  United States  United States  23-05-2022  29-05-2022     7  2022    21
# 5768  United States  United States  30-05-2022  05-06-2022     7  2022    22
# 5769  United States  United States  06-06-2022  12-06-2022     7  2022    23
#
# ...

# %%
country_deaths = df.groupby('country')['total_deaths'].sum().sort_values(ascending=False)

# %%
country_deaths
# Out:
# country
# United States     8407409.0
# Germany           2529149.0
# Mexico            2503250.0
# Italy             1707936.0
# Britain           1691666.0
# South Africa      1614666.0
# France            1599319.0
# Iran              1260978.7
# Poland            1227358.0
# Spain             1139522.0
# Colombia           820104.0
# South Korea        764026.0
# Romania            755665.0
# Canada             675940.0
# Peru               598720.5
# Netherlands        428523.0
# Australia          377170.0
# Hungary            358233.0
# Greece             340743.0
# Chile              337033.0
# Bulgaria           332322.0
# Czech Republic     320135.0
# Portugal           314471.0
# Belgium            295727.0
# Ecuador            271768.0
# Sweden             233352.0
# Austria            227019.0
# Guatemala          213152.0
# Switzerland        182593.0
# Slovakia           156516.0
# Croatia            146469.0
# Denmark            143618.0
# Finland            140780.0
# ...

# %%
plt.figure(figsize=(12, 8))
country_deaths.plot(kind='bar', color='orange')
plt.title('Total death by Countrty')
plt.xlabel('country')
plt.ylabel('Total Deaths')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing 'total_deaths' column

plt.figure(figsize=(12, 8))
plt.hist(df['total_deaths'].dropna(), bins=30, color='orange', edgecolor='green')  # Use dropna() to drop NaN values if any
plt.title('Distribution of Total Deaths')
plt.xlabel('Total Deaths')
plt.ylabel('Frequency')
plt.show()
